# %%
# Dataset 1 : Movies
# Output : Awards : Yes or No
# SVC() --> kernel = 'linear'

import numpy as np
import time
import pandas as pd
import io
import matplotlib.pyplot as plt

# split your datas between training and test
from sklearn.model_selection import train_test_split
# comparing datas
from sklearn.metrics import accuracy_score
# model 
from sklearn.svm import SVC
# cross validation
from sklearn.model_selection import cross_val_score
# validation curve
from yellowbrick.model_selection import validation_curve
# learning curve
from sklearn.model_selection import learning_curve
# will be used to convert string into float
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

#dataset
a = io.open('Movie Dataset.csv', encoding='latin-1')
df = pd.read_csv(a)
df = df.take([i for i in range(1300)], axis = 0)
df = df.apply(LabelEncoder().fit_transform)

#input
X = df.drop(columns=['Awards'])

#output
y = df['Awards']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

time1 = time.perf_counter()

model = SVC(kernel = 'linear')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'linear') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 126.38368438100042 s
# [0.88709677 0.88709677 0.88172043 0.88172043 0.88709677 0.89189189
#  0.89189189]
# Accuracy score = 0.8869307095113548
# Test score = 0.9
# time for doing the learning curve = 1080.806872098 s

# %%
# Dataset 1 : Movies
# Output : Awards : Yes or No
# SVC() --> kernel = 'poly'

import numpy as np
import time
import pandas as pd
import io
import matplotlib.pyplot as plt

# split your datas between training and test
from sklearn.model_selection import train_test_split
# comparing datas
from sklearn.metrics import accuracy_score
# model 
from sklearn.svm import SVC
# cross validation
from sklearn.model_selection import cross_val_score
# validation curve
from yellowbrick.model_selection import validation_curve
# learning curve
from sklearn.model_selection import learning_curve
# will be used to convert string into float
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

#dataset
a = io.open('Movie Dataset.csv', encoding='latin-1')
df = pd.read_csv(a)
df = df.take([i for i in range(1300)], axis = 0)
df = df.apply(LabelEncoder().fit_transform)

#input
X = df.drop(columns=['Awards'])

#output
y = df['Awards']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

time1 = time.perf_counter()

model = SVC(kernel = 'poly')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'poly') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 1.1535702679975657 s
# [0.88709677 0.88709677 0.88172043 0.88172043 0.88172043 0.88648649
#  0.88648649]
# Accuracy score = 0.8846182588118071
# Test score = 0.8615384615384616
# time for doing the learning curve = 12.94036163000419 s

# %%
# Dataset 1 : Movies
# Output : Awards : Yes or No
# SVC() --> kernel = 'rbf'

import numpy as np
import time
import pandas as pd
import io
import matplotlib.pyplot as plt

# split your datas between training and test
from sklearn.model_selection import train_test_split
# comparing datas
from sklearn.metrics import accuracy_score
# model 
from sklearn.svm import SVC
# cross validation
from sklearn.model_selection import cross_val_score
# validation curve
from yellowbrick.model_selection import validation_curve
# learning curve
from sklearn.model_selection import learning_curve
# will be used to convert string into float
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

#dataset
a = io.open('Movie Dataset.csv', encoding='latin-1')
df = pd.read_csv(a)
df = df.take([i for i in range(1300)], axis = 0)
df = df.apply(LabelEncoder().fit_transform)

#input
X = df.drop(columns=['Awards'])

#output
y = df['Awards']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

time1 = time.perf_counter()

model = SVC(kernel = 'rbf')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.4524657589990966 s
# [0.88709677 0.88709677 0.88172043 0.88172043 0.88172043 0.88648649
#  0.88648649]
# Accuracy score = 0.8846182588118071
# Test score = 0.8846153846153846
# time for doing the learning curve = 9.937501665999662 s

# %%
# Dataset 1 : Movies
# Output : Awards : Yes or No
# SVC() --> kernel = 'sigmoid'

import numpy as np
import time
import pandas as pd
import io
import matplotlib.pyplot as plt

# split your datas between training and test
from sklearn.model_selection import train_test_split
# comparing datas
from sklearn.metrics import accuracy_score
# model 
from sklearn.svm import SVC
# cross validation
from sklearn.model_selection import cross_val_score
# validation curve
from yellowbrick.model_selection import validation_curve
# learning curve
from sklearn.model_selection import learning_curve
# will be used to convert string into float
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

#dataset
a = io.open('Movie Dataset.csv', encoding='latin-1')
df = pd.read_csv(a)
df = df.take([i for i in range(1300)], axis = 0)
df = df.apply(LabelEncoder().fit_transform)

#input
X = df.drop(columns=['Awards'])

#output
y = df['Awards']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

time1 = time.perf_counter()

model = SVC(kernel = 'sigmoid')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'sigmoid') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.22729876700032037 s
# [0.85483871 0.80645161 0.88172043 0.88172043 0.79032258 0.76756757
#  0.72972973]
# Accuracy score = 0.8160501515340225
# Test score = 0.8269230769230769
# time for doing the learning curve = 3.376475795999795 s

# %%
# Dataset 1 : Movies
# Output : Awards : Yes or No
# SVC() --> kernel = 'precomputed'

import numpy as np
import time
import pandas as pd
import io
import matplotlib.pyplot as plt

# split your datas between training and test
from sklearn.model_selection import train_test_split
# comparing datas
from sklearn.metrics import accuracy_score
# model 
from sklearn.svm import SVC
# cross validation
from sklearn.model_selection import cross_val_score
# validation curve
from yellowbrick.model_selection import validation_curve
# learning curve
from sklearn.model_selection import learning_curve
# will be used to convert string into float
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

#dataset
a = io.open('Movie Dataset.csv', encoding='latin-1')
df = pd.read_csv(a)
df = df.take([i for i in range(1300)], axis = 0)
df = df.apply(LabelEncoder().fit_transform)

#input
X = df.drop(columns=['Awards'])

#output
y = df['Awards']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

time1 = time.perf_counter()

model = SVC(kernel = 'precomputed')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'sigmoid') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ry/8803myjd0q12dyd2h81ryjcm0000gn/T/ipykernel_8870/2231066863.py in <module>
#      43 model = SVC(kernel = 'precomputed')
#      44
# ---> 45 model.fit(X_train,y_train)
#      46
#      47 validation = cross_val_score(model, X, y, cv=7)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     196
#     197         if self.kernel == "precomputed" and n_samples != X.shape[1]:
# --> 198             raise ValueError(
#     199                 "Precomputed matrix must be a square matrix."
#     200                 " Input is a {}x{} matrix.".format(X.shape[0], X.shape[1])
#
# ValueError: Precomputed matrix must be a square matrix. Input is a 1040x8 matrix.

# %%
# Hyperparameters : kernel = 'rbf'
# Vary : C

time1 = time.perf_counter()

#validation curve
print(validation_curve(SVC(kernel = 'rbf') , 
                       X , y , 
                       param_name ='C', 
                       param_range=np.linspace(0,10,50), 
                       cv=7, 
                       score='accuracy'))

#learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time2 = time.perf_counter()
timeA = time2 - time1
print('time for doing the validation and learning curve =',timeA,'s')

#means
train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

#standard deviation
train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

# plot the figure
plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')

plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc = 'best')
# Out:
# ValidationCurve(ax=<AxesSubplot:title={'center':'Validation Curve for SVC'}, xlabel='C', ylabel='score'>,
#                 cv=7, estimator=SVC(), param_name='C',
#                 param_range=array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ]))
# time for doing the validation and learning curve = 49.67319003599914 s

# %%
# Hyperparameters : kernel = 'rbf', C = default
# Vary : gamma = 'scale'

time1 = time.perf_counter()

model = SVC(kernel = 'rbf', gamma = 'scale')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf', gamma = 'scale') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.42916972000057285 s
# [0.88709677 0.88709677 0.88172043 0.88172043 0.88172043 0.88648649
#  0.88648649]
# Accuracy score = 0.8846182588118071
# Test score = 0.8884615384615384
# time for doing the learning curve = 6.391628019999189 s

# %%
# Hyperparameters : kernel = 'rbf', C = default
# Vary : gamma = 'auto'

time1 = time.perf_counter()

model = SVC(kernel = 'rbf', gamma = 'auto')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf', gamma = 'auto') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.7437175920003938 s
# [0.88709677 0.88709677 0.88172043 0.88172043 0.88172043 0.88648649
#  0.88648649]
# Accuracy score = 0.8846182588118071
# Test score = 0.8884615384615384
# time for doing the learning curve = 17.063056536999284 s
