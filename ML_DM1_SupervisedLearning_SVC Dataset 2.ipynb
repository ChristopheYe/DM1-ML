# %%
# Dataset 2 : Wines
# Output : Type of wine : red or white
# SVC() --> kernel = 'linear'

import numpy as np
import time
import pandas as pd
import io
import matplotlib.pyplot as plt

# split your datas between training and test
from sklearn.model_selection import train_test_split
# comparing datas
from sklearn.metrics import accuracy_score
# model 
from sklearn.svm import SVC
# cross validation
from sklearn.model_selection import cross_val_score
# validation curve
from yellowbrick.model_selection import validation_curve
# learning curve
from sklearn.model_selection import learning_curve
# will be used to convert string into float
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

#dataset
a = io.open('wine-quality-white-and-red.csv', encoding='latin-1')
df = pd.read_csv(a)
df = df.take([10*i for i in range(649)], axis = 0)
df = df.apply(LabelEncoder().fit_transform)

#input
X = df.drop(columns=['type'])

#output
y = df['type']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

time1 = time.perf_counter()

model = SVC(kernel = 'linear')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'linear') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.04849885100003348 s
# [0.97849462 0.98924731 1.         1.         0.98924731 0.98913043
#  1.        ]
# Accuracy score = 0.9923028117277767
# Test score = 0.9923076923076923
# time for doing the learning curve = 3.820306678999998 s

# %%
# Dataset 2 : Wines
# Output : Type of wine : red or white
# SVC() --> kernel = 'poly'

import numpy as np
import time
import pandas as pd
import io
import matplotlib.pyplot as plt

# split your datas between training and test
from sklearn.model_selection import train_test_split
# comparing datas
from sklearn.metrics import accuracy_score
# model 
from sklearn.svm import SVC
# cross validation
from sklearn.model_selection import cross_val_score
# validation curve
from yellowbrick.model_selection import validation_curve
# learning curve
from sklearn.model_selection import learning_curve
# will be used to convert string into float
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

#dataset
a = io.open('wine-quality-white-and-red.csv', encoding='latin-1')
df = pd.read_csv(a)
df = df.take([10*i for i in range(649)], axis = 0)
df = df.apply(LabelEncoder().fit_transform)

#input
X = df.drop(columns=['type'])

#output
y = df['type']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

time1 = time.perf_counter()

model = SVC(kernel = 'poly')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'poly') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.07133427200000142 s
# [0.98924731 0.98924731 1.         1.         0.97849462 1.
#  1.        ]
# Accuracy score = 0.9938556067588326
# Test score = 1.0
# time for doing the learning curve = 0.7805818539999905 s

# %%
# Dataset 2 : Wines
# Output : Type of wine : red or white
# SVC() --> kernel = 'rbf'

import numpy as np
import time
import pandas as pd
import io
import matplotlib.pyplot as plt

# split your datas between training and test
from sklearn.model_selection import train_test_split
# comparing datas
from sklearn.metrics import accuracy_score
# model 
from sklearn.svm import SVC
# cross validation
from sklearn.model_selection import cross_val_score
# validation curve
from yellowbrick.model_selection import validation_curve
# learning curve
from sklearn.model_selection import learning_curve
# will be used to convert string into float
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

#dataset
a = io.open('wine-quality-white-and-red.csv', encoding='latin-1')
df = pd.read_csv(a)
df = df.take([10*i for i in range(649)], axis = 0)
df = df.apply(LabelEncoder().fit_transform)

#input
X = df.drop(columns=['type'])

#output
y = df['type']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

time1 = time.perf_counter()

model = SVC(kernel = 'rbf')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.05387805200001594 s
# [0.97849462 0.98924731 1.         1.         1.         1.
#  1.        ]
# Accuracy score = 0.9953917050691244
# Test score = 1.0
# time for doing the learning curve = 0.8881028929999957 s

# %%
# Dataset 2 : Wines
# Output : Type of wine : red or white
# SVC() --> kernel = 'sigmoid'

import numpy as np
import time
import pandas as pd
import io
import matplotlib.pyplot as plt

# split your datas between training and test
from sklearn.model_selection import train_test_split
# comparing datas
from sklearn.metrics import accuracy_score
# model 
from sklearn.svm import SVC
# cross validation
from sklearn.model_selection import cross_val_score
# validation curve
from yellowbrick.model_selection import validation_curve
# learning curve
from sklearn.model_selection import learning_curve
# will be used to convert string into float
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

#dataset
a = io.open('wine-quality-white-and-red.csv', encoding='latin-1')
df = pd.read_csv(a)
df = df.take([10*i for i in range(649)], axis = 0)
df = df.apply(LabelEncoder().fit_transform)

#input
X = df.drop(columns=['type'])

#output
y = df['type']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

time1 = time.perf_counter()

model = SVC(kernel = 'sigmoid')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'sigmoid') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.1215718539970112 s
# [0.65591398 0.86021505 0.80645161 0.75268817 0.76344086 0.75
#  0.85869565]
# Accuracy score = 0.7782007613704669
# Test score = 0.7230769230769231
# time for doing the learning curve = 5.6864370979965315 s

# %%
# Hyperparameters : kernel = 'rbf'
# Vary : C

time1 = time.perf_counter()

#validation curve
print(validation_curve(SVC(kernel = 'rbf') , 
                       X , y , 
                       param_name ='C', 
                       param_range=np.linspace(0,10,50), 
                       cv=7, 
                       score='accuracy'))

#learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time2 = time.perf_counter()
timeA = time2 - time1
print('time for doing the validation and learning curve =',timeA,'s')

#means
train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

#standard deviation
train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

# plot the figure
plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')

plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc = 'best')
# Out:
# ValidationCurve(ax=<AxesSubplot:title={'center':'Validation Curve for SVC'}, xlabel='C', ylabel='score'>,
#                 cv=7, estimator=SVC(), param_name='C',
#                 param_range=array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ]))
# time for doing the validation and learning curve = 4.298122341000067 s

# %%
# Hyperparameters : kernel = 'rbf' , C =5 
# Vary : gamma --> 'scale'

time1 = time.perf_counter()

model = SVC(kernel = 'rbf',  C =5, gamma = 'scale')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf',  C =5, gamma = 'scale') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.05184798100003718 s
# [0.98924731 0.98924731 1.         1.         1.         1.
#  1.        ]
# Accuracy score = 0.9969278033794163
# Test score = 1.0
# time for doing the learning curve = 0.8337034149999454 s

# %%
# Hyperparameters : kernel = 'rbf' , C =5 
# Vary : gamma --> 'auto'

time1 = time.perf_counter()

model = SVC(kernel = 'rbf',  C =5, gamma = 'auto')

model.fit(X_train,y_train)

validation = cross_val_score(model, X, y, cv=7)

#time after predicting the test sets
time2 = time.perf_counter()
timeA = time2 - time1
print('time after training the sets and cross validation =',timeA,'s')

print(validation)
print('Accuracy score =', validation.mean())

#Testing the test set
predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)
print('Test score =', score)

#Plot the learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf',  C =5, gamma = 'auto') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time3 = time.perf_counter()
timeB = time3 - time2
print('time for doing the learning curve =',timeB,'s')

train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')


plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc ='best')
# Out:
# time after training the sets and cross validation = 0.19991854900001726 s
# [0.75268817 0.75268817 0.75268817 0.75268817 0.75268817 0.76086957
#  0.76086957]
# Accuracy score = 0.7550257129499768
# Test score = 0.7615384615384615
# time for doing the learning curve = 2.5536608469999464 s

# %%
# Hyperparameters : kernel = 'rbf', C =5, gamma ='scale' 
# Vary : tol

time1 = time.perf_counter()

#validation curve
print(validation_curve(SVC(kernel = 'rbf', C =5, gamma ='scale'  ) , 
                       X , y , 
                       param_name ='tol', 
                       param_range=np.linspace(0,0.01,50), 
                       cv=7, 
                       score='accuracy'))

#learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf', C =5, gamma ='scale') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time2 = time.perf_counter()
timeA = time2 - time1
print('time for doing the validation and learning curve =',timeA,'s')

#means
train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

#standard deviation
train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

# plot the figure
plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')

plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc = 'best')
# Out:
# ValidationCurve(ax=<AxesSubplot:title={'center':'Validation Curve for SVC'}, xlabel='tol', ylabel='score'>,
#                 cv=7, estimator=SVC(C=5), param_name='tol',
#                 param_range=array([0.        , 0.00020408, 0.00040816, 0.00061224, 0.00081633,
#        0.00102041, 0.00122449, 0.00142857, 0.00163265, 0.00183673,
#        0.00204082, 0.0022449 , 0.00244898, 0.00265306, 0.00285714,
#        0.00306122, 0.00326531, 0.00346939, 0.00367347, 0.00387755,
#        0.00408163, 0.00428571, 0.0044898 , 0.00469388, 0.00489796,
#        0.00510204, 0.00530612, 0.0055102 , 0.00571429, 0.00591837,
#        0.00612245, 0.00632653, 0.00653061, 0.00673469, 0.00693878,
#        0.00714286, 0.00734694, 0.00755102, 0.0077551 , 0.00795918,
#        0.00816327, 0.00836735, 0.00857143, 0.00877551, 0.00897959,
#        0.00918367, 0.00938776, 0.00959184, 0.00979592, 0.01      ]))
# time for doing the validation and learning curve = 7.5288547899999685 s

# %%
# Hyperparameters : kernel = 'rbf', C=5, gamma ='scale', tol = default 
# Vary : cache_size

time1 = time.perf_counter()

#validation curve
print(validation_curve(SVC(kernel = 'rbf', C =5, gamma ='scale') , 
                       X , y , 
                       param_name ='cache_size', 
                       param_range=np.linspace(50,350,30), 
                       cv=7, 
                       score='accuracy'))

#learning curve
train_sizes, train_scores, valid_scores = learning_curve(SVC(kernel = 'rbf', C =5, gamma ='scale') , 
                                                         X , y , 
                                                         train_sizes=np.linspace(0.01,1,50), 
                                                         cv=7, 
                                                         scoring = 'accuracy', 
                                                         n_jobs= -1)

time2 = time.perf_counter()
timeA = time2 - time1
print('time for doing the validation and learning curve =',timeA,'s')

#means
train_mean = np.mean(train_scores, axis = 1)
valid_mean = np.mean(valid_scores, axis = 1)

#standard deviation
train_std = np.std(train_scores, axis = 1)
valid_std = np.std(valid_scores, axis = 1)

# plot the figure
plt.plot(train_sizes,train_mean, label = 'Training score')
plt.plot(train_sizes,valid_mean, label = 'Cross-validation score')
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color = '#DDDDDD')
plt.fill_between(train_sizes, valid_mean - valid_std, valid_mean + valid_std, color = '#DDDDDD')

plt.title('Learning curve')
plt.xlabel('Training size')
plt.ylabel('Accuracy score')
plt.legend(loc = 'best')
# Out:
# ValidationCurve(ax=<AxesSubplot:title={'center':'Validation Curve for SVC'}, xlabel='cache_size', ylabel='score'>,
#                 cv=7, estimator=SVC(C=5), param_name='cache_size',
#                 param_range=array([ 50.        ,  60.34482759,  70.68965517,  81.03448276,
#         91.37931034, 101.72413793, 112.06896552, 122.4137931 ,
#        132.75862069, 143.10344828, 153.44827586, 163.79310345,
#        174.13793103, 184.48275862, 194.82758621, 205.17241379,
#        215.51724138, 225.86206897, 236.20689655, 246.55172414,
#        256.89655172, 267.24137931, 277.5862069 , 287.93103448,
#        298.27586207, 308.62068966, 318.96551724, 329.31034483,
#        339.65517241, 350.        ]))
# time for doing the validation and learning curve = 2.5626442349998797 s
